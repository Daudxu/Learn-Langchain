# %%
pip install langchain==0.0.235 openai==0.28.1 python-dotenv
# Out:
# Collecting langchain==0.0.235
#   Using cached langchain-0.0.235-py3-none-any.whl.metadata (14 kB)
# Collecting openai==0.28.1
#   Using cached openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# Collecting PyYAML>=5.4.1 (from langchain==0.0.235)
#   Downloading PyYAML-6.0.2-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain==0.0.235)
#   Downloading SQLAlchemy-2.0.36-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.0.235)
#   Downloading aiohttp-3.11.10-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain==0.0.235)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain==0.0.235)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting langsmith<0.0.8,>=0.0.7 (from langchain==0.0.235)
#   Downloading langsmith-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Collecting numexpr<3.0.0,>=2.8.4 (from langchain==0.0.235)
#   Downloading numexpr-2.10.2-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Collecting numpy<2,>=1 (from langchain==0.0.235)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain==0.0.235)
#   Using cached openapi_schema_pydantic-1.2.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting pydantic<2,>=1 (from langchain==0.0.235)
#   Downloading pydantic-1.10.19-cp310-cp310-win_amd64.whl.metadata (153 kB)
# Collecting requests<3,>=2 (from langchain==0.0.235)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.0.235)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tqdm (from openai==0.28.1)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Downloading multidict-6.1.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Downloading propcache-0.2.1-cp310-cp310-win_amd64.whl.metadata (9.5 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.235)
#   Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl.metadata (71 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.235)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.235)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\workspace\learn-langchain\.conda\lib\site-packages (from pydantic<2,>=1->langchain==0.0.235) (4.12.2)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain==0.0.235)
#   Downloading charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain==0.0.235)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain==0.0.235)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain==0.0.235)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain==0.0.235)
#   Downloading greenlet-3.1.1-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in d:\workspace\learn-langchain\.conda\lib\site-packages (from tqdm->openai==0.28.1) (0.4.6)
# Requirement already satisfied: packaging>=17.0 in d:\workspace\learn-langchain\.conda\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.235) (24.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.235)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain-0.0.235-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.4 MB/s eta 0:00:00
# Downloading openai-0.28.1-py3-none-any.whl (76 kB)
# Downloading aiohttp-3.11.10-cp310-cp310-win_amd64.whl (441 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Downloading langsmith-0.0.7-py3-none-any.whl (26 kB)
# Downloading numexpr-2.10.2-cp310-cp310-win_amd64.whl (144 kB)
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/15.8 MB 2.1 MB/s eta 0:00:08
#    -------- ------------------------------- 3.4/15.8 MB 5.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.5/15.8 MB 5.2 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/15.8 MB 5.8 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.8 MB 6.3 MB/s eta 0:00:02
#    ------------------------- -------------- 10.0/15.8 MB 6.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.8 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 1.4 MB/s eta 0:00:00
# Using cached openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
# Downloading pydantic-1.10.19-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.9 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading SQLAlchemy-2.0.36-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------------ --------- 1.6/2.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.3 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl (102 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl (51 kB)
# Downloading greenlet-3.1.1-cp310-cp310-win_amd64.whl (298 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Downloading multidict-6.1.0-cp310-cp310-win_amd64.whl (28 kB)
# Downloading propcache-0.2.1-cp310-cp310-win_amd64.whl (44 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl (90 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: urllib3, tqdm, tenacity, PyYAML, pydantic, propcache, numpy, mypy-extensions, multidict, marshmallow, idna, greenlet, frozenlist, charset-normalizer, certifi, attrs, async-timeout, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, requests, openapi-schema-pydantic, numexpr, aiosignal, langsmith, dataclasses-json, aiohttp, openai, langchain
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.4 aiohttp-3.11.10 aiosignal-1.3.1 async-timeout-4.0.3 attrs-24.2.0 certifi-2024.8.30 charset-normalizer-3.4.0 dataclasses-json-0.5.14 frozenlist-1.5.0 greenlet-3.1.1 idna-3.10 langchain-0.0.235 langsmith-0.0.7 marshmallow-3.23.1 multidict-6.1.0 mypy-extensions-1.0.0 numexpr-2.10.2 numpy-1.26.4 openai-0.28.1 openapi-schema-pydantic-1.2.4 propcache-0.2.1 pydantic-1.10.19 requests-2.32.3 tenacity-8.5.0 tqdm-4.67.1 typing-inspect-0.9.0 urllib3-2.2.3 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Hello Langchain

# %%
import os
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage
from dotenv import load_dotenv
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
chat = ChatOpenAI(temperature=0)
response = chat([ HumanMessage(content="Hello Langchain!") ])
print(response)
# Out:
# content='Hello! How can I assist you today?' additional_kwargs={} example=False

# %%
print(1111)
# Out:
# 1111
